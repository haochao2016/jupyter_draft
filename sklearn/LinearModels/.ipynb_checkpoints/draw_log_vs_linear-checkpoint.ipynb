# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 1
b = 1

x = np.arange(0,2, 0.1)
y0 = w * x + b
y1 = np.exp(y0)
y1

plt.plot(x, y0, label='e^wx+b')
plt.plot(x, y1, label='wx+b')
plt.legend()
plt.show()
