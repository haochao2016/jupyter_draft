# %%
# Plot a decision tree

import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import graphviz as pgh

# %% [raw]
# dataset = np.loadtxt('D:\\docu\\Book\\ML\\python_ml_bundle_7books\\xgboost_with_python\\code\\chapter_07\\pima-indians-diabetes.csv', delimiter=',')
# X = dataset[:, :-1]
# y = dataset[:, -1]
# model = xgb.XGBClassifier(use_label_encoder=False)
# model.fit(X, y)

# %%
xgb.plot_tree(model, num_trees=0, rankdir = 'LR')
plt.show()
